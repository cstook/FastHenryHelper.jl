# %% [markdown]
# # Example 2: Four square loops
#
# This example demonstrates using groups to simplify repetitive structures.

# %% [markdown]
# Load the module.

# %%
using FastHenryHelper

# %% [markdown]
# Create a group for one square loop 10mm on a side.

# %%
squareloop = Group(
    elements=[
        Comment("loop start"),
        n1 = Node(0,0,0),
        n2 = Node(10,0,0),
        n3 = Node(10,10,0),
        n4 = Node(0,10,0),
        n5 = Node(0,1,0), # leave a 1mm gap for the port
        connectnodes([n1,n2,n3,n4,n5], SegmentParameters(h=0.5, w=1.5))...,
        Comment("loop end")
    ],
    terms = Dict(:a=>n1,:b=>n5) # ports will be between :a and :b
)
# Out:
# * loop start
# N_1 x=0.000000000e+00 y=0.000000000e+00 z=0.000000000e+00
# N_2 x=1.000000000e+01 y=0.000000000e+00 z=0.000000000e+00
# N_3 x=1.000000000e+01 y=1.000000000e+01 z=0.000000000e+00
# N_4 x=0.000000000e+00 y=1.000000000e+01 z=0.000000000e+00
# N_5 x=0.000000000e+00 y=1.000000000e+00 z=0.000000000e+00
# E_6 N_1 N_2
# +  w=1.500000000e+00 h=5.000000000e-01
# E_7 N_2 N_3
# +  w=1.500000000e+00 h=5.000000000e-01
# E_8 N_3 N_4
# +  w=1.500000000e+00 h=5.000000000e-01
# E_9 N_4 N_5
# +  w=1.500000000e+00 h=5.000000000e-01
# * loop end

# %% [markdown]
# Create an array of four square loops, each one shifted 10mm on z axis.

# %%
loops = Array{Group}(4)
z = [0.0, 10.0, 20.0, 30.0]
for i in eachindex(loops)
    loops[i] = transform(squareloop, txyz(0,0,z[i]))
end

# %% [markdown]
# Create the top level group.

# %%
fourloops = Group(
    elements=[
        Comment("Four loops 10mm on a side offset by 10mm in z"),
        Units("mm"),
        Comment(""),
        Comment("sigma for copper, 25 filiments per segment"),
        Default(sigma=62.1e6*1e-3, nwinc=5, nhinc=5),
        Comment(""),
        Comment("the loops"),
        loops...,
        Comment(""),
        Comment("define three ports"),
        External(loops[3][:b],loops[4][:b],"port_1"),
        External(loops[2][:a],loops[2][:b],"port_2"),
        External(loops[1][:a],loops[1][:b],"port_3"),
        Comment(""),
        Comment("define frequencies"),
        Freq(min=1e-1, max=1e9, ndec=0.05),
        Comment(""),
        Comment("always need end"),
        End()
    ]
)
# Out:
# * Four loops 10mm on a side offset by 10mm in z
# .units mm
# *
# * sigma for copper, 25 filiments per segment
# .default
# +  nhinc=5 nwinc=5
# +  sigma=6.210000000e+04
# *
# * the loops
# * loop start
# N_1 x=0.000000000e+00 y=0.000000000e+00 z=0.000000000e+00
# N_2 x=1.000000000e+01 y=0.000000000e+00 z=0.000000000e+00
# N_3 x=1.000000000e+01 y=1.000000000e+01 z=0.000000000e+00
# N_4 x=0.000000000e+00 y=1.000000000e+01 z=0.000000000e+00
# N_5 x=0.000000000e+00 y=1.000000000e+00 z=0.000000000e+00
# E_6 N_1 N_2
# +  w=1.500000000e+00 h=5.000000000e-01
# +  wx=0.000000000e+00 wy=1.000000000e+00 wz=0.000000000e+00
# E_7 N_2 N_3
# +  w=1.500000000e+00 h=5.000000000e-01
# +  wx=-1.000000000e+00 wy=0.000000000e+00 wz=0.000000000e+00
# E_8 N_3 N_4
# +  w=1.500000000e+00 h=5.000000000e-01
# +  wx=0.000000000e+00 wy=-1.000000000e+00 wz=0.000000000e+00
# E_9 N_4 N_5
# +  w=1.500000000e+00 h=5.000000000e-01
# +  wx=1.000000000e+00 wy=0.000000000e+00 wz=0.000000000e+00
# * loop end
# * loop start
# N_10 x=0.000000000e+00 y=0.000000000e+00 z=1.000000000e+01
# N_11 x=1.000000000e+01 y=0.000000000e+00 z=1.000000000e+01
# N_12 x=1.000000000e+01 y=1.000000000e+01 z=1.000000000e+01
# N_13 x=0.000000000e+00 y=1.000000000e+01 z=1.000000000e+01
# N_14 x=0.000000000e+00 y=1.000000000e+00 z=1.000000000e+01
# E_15 N_10 N_11
# +  w=1.500000000e+00 h=5.000000000e-01
# +  wx=0.000000000e+00 wy=1.000000000e+00 wz=0.000000000e+00
# E_16 N_11 N_12
# +  w=1.500000000e+00 h=5.000000000e-01
# +  wx=-1.000000000e+00 wy=0.000000000e+00 wz=0.000000000e+00
# E_17 N_12 N_13
# +  w=1.500000000e+00 h=5.000000000e-01
# +  wx=0.000000000e+00 wy=-1.000000000e+00 wz=0.000000000e+00
# E_18 N_13 N_14
# +  w=1.500000000e+00 h=5.000000000e-01
# +  wx=1.000000000e+00 wy=0.000000000e+00 wz=0.000000000e+00
# * loop end
# * loop start
# N_19 x=0.000000000e+00 y=0.000000000e+00 z=2.000000000e+01
# N_20 x=1.000000000e+01 y=0.000000000e+00 z=2.000000000e+01
# N_21 x=1.000000000e+01 y=1.000000000e+01 z=2.000000000e+01
# N_22 x=0.000000000e+00 y=1.000000000e+01 z=2.000000000e+01
# N_23 x=0.000000000e+00 y=1.000000000e+00 z=2.000000000e+01
# E_24 N_19 N_20
# +  w=1.500000000e+00 h=5.000000000e-01
# +  wx=0.000000000e+00 wy=1.000000000e+00 wz=0.000000000e+00
# E_25 N_20 N_21
# +  w=1.500000000e+00 h=5.000000000e-01
# +  wx=-1.000000000e+00 wy=0.000000000e+00 wz=0.000000000e+00
# E_26 N_21 N_22
# +  w=1.500000000e+00 h=5.000000000e-01
# +  wx=0.000000000e+00 wy=-1.000000000e+00 wz=0.000000000e+00
# E_27 N_22 N_23
# +  w=1.500000000e+00 h=5.000000000e-01
# +  wx=1.000000000e+00 wy=0.000000000e+00 wz=0.000000000e+00
# * loop end
# * loop start
# N_28 x=0.000000000e+00 y=0.000000000e+00 z=3.000000000e+01
# N_29 x=1.000000000e+01 y=0.000000000e+00 z=3.000000000e+01
# N_30 x=1.000000000e+01 y=1.000000000e+01 z=3.000000000e+01
# N_31 x=0.000000000e+00 y=1.000000000e+01 z=3.000000000e+01
# N_32 x=0.000000000e+00 y=1.000000000e+00 z=3.000000000e+01
# E_33 N_28 N_29
# +  w=1.500000000e+00 h=5.000000000e-01
# +  wx=0.000000000e+00 wy=1.000000000e+00 wz=0.000000000e+00
# E_34 N_29 N_30
# +  w=1.500000000e+00 h=5.000000000e-01
# +  wx=-1.000000000e+00 wy=0.000000000e+00 wz=0.000000000e+00
# E_35 N_30 N_31
# +  w=1.500000000e+00 h=5.000000000e-01
# +  wx=0.000000000e+00 wy=-1.000000000e+00 wz=0.000000000e+00
# E_36 N_31 N_32
# +  w=1.500000000e+00 h=5.000000000e-01
# +  wx=1.000000000e+00 wy=0.000000000e+00 wz=0.000000000e+00
# * loop end
# *
# * define three ports
# .external N_23 N_32 port_1
# .external N_10 N_14 port_2
# .external N_1 N_5 port_3
# *
# * define frequencies
# .freq fmin=1.000000000e-01 fmax=1.000000000e+09 ndec=5.000000000e-02
# *
# * always need end
# .end

# %% [markdown]
# Plot of `fourloops`

# %%
using Plots
gr()  #  use plotlyjs() or plotly() for interactive plot
plot(fourloops)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 141.339,376.378 490.157,376.378 490.157,27.5591 141.339,27.5591
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="141" y="27" width="350" height="350"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   141.339,279.55 300.489,142.028
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.489,142.028 490.157,238.856
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   141.339,268.103 300.489,130.581
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.489,130.581 490.157,227.409
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   141.339,256.656 300.489,119.135
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.489,119.135 490.157,215.962
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   141.339,245.21 300.489,107.688
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.489,107.688 490.157,204.515
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   141.339,233.763 300.489,96.2406
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.489,96.2406 490.157,193.068
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   141.339,222.316 300.489,84.7937
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.489,84.7937 490.157,181.621
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   141.339,210.869 300.489,73.3468
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.489,73.3468 490.157,170.174
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   141.339,199.422 300.489,61.8998
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.489,61.8998 490.157,158.727
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   141.339,187.975 300.489,50.4529
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.489,50.4529 490.157,147.281
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   141.339,176.528 300.489,39.006
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.489,39.006 490.157,135.834
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   141.339,165.081 300.489,27.5591
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.489,27.5591 490.157,124.387
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   148.173,283.039 307.324,145.518
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   307.324,145.518 307.324,31.0482
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   177.506,298.014 336.657,160.492
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   336.657,160.492 336.657,46.0231
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   206.84,312.989 365.99,175.467
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   365.99,175.467 365.99,60.998
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   236.173,327.964 395.323,190.442
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   395.323,190.442 395.323,75.9729
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   265.506,342.939 424.657,205.417
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   424.657,205.417 424.657,90.9477
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   294.839,357.914 453.99,220.392
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   453.99,220.392 453.99,105.923
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   324.172,372.889 483.323,235.367
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   483.323,235.367 483.323,120.898
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   147.074,274.595 336.742,371.422
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   147.074,274.595 147.074,160.125
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   171.687,253.326 361.355,350.154
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   171.687,253.326 171.687,138.857
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   196.3,232.058 385.969,328.885
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   196.3,232.058 196.3,117.589
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   220.914,210.789 410.582,307.617
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   220.914,210.789 220.914,96.32
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   245.527,189.521 435.196,286.348
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   245.527,189.521 245.527,75.0516
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   270.141,168.252 459.809,265.08
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fi

# %% [markdown]
# Write fourloops to file.

# %%
open("fourloops.inp","w") do io
    show(io,fourloops)
end
