# %% [markdown]
# # Example 1: A simple example from the FastHenry documentation.
# This example is a recreation of the example in section 1.2 of "[FastHenry User's Guide](https://github.com/ediloren/FastHenry2/blob/master/doc/FastHenry_User_Guide.pdf)" using FastHeneryHelper.

# %%
using FastHenryHelper

# %% [markdown]
# Create a group of FastHenry elements for FastHenry to compute the loop inductance of an L shaped trace over a ground plane with the trace's return path through the plane.

# %%
sp = SegmentParameters(w=8,h=1)
example1 = Group(
    elements = [Comment("A FastHenry example using a reference plane"),
                Units("mils"),
                g = UniformPlane(
                    x1=0,    y1=0,    z1=0,
                    x2=1000, y2=0,    z2=0,
                    x3=1000, y3=1000, z3=0,
                    thick= 1.2,
                    seg1=20, seg2=20,
                    nodes=[nin = Node("in",800,800,0), nout = Node("out",0,200,0)]
                    ),
                Default(SegmentParameters(sigma=62.1e6*2.54e-5,nwinc=8, nhinc=1)),
                n1 = Node("1",0,200,1.5),
                n2 = Node(800,200,1.5),
                n3 = Node(800,800,1.5),
                Segment(n1,n2,sp),
                Segment(n2,n3,sp),
                Equiv([nin,n3]),
                External(n1,nout),
                Freq(min=1e-1, max=1e9, ndec=0.05),
                End()
        ]
    )
# Out:
# * A FastHenry example using a reference plane
# .units mils
# G_1
# + x1=0.000000000e+00 y1=0.000000000e+00 z1=0.000000000e+00
# + x2=1.000000000e+03 y2=0.000000000e+00 z2=0.000000000e+00
# + x3=1.000000000e+03 y3=1.000000000e+03 z3=0.000000000e+00
# + thick=1.200000000e+00 seg1=20 seg2=20
# + Nin (8.000000000e+02,8.000000000e+02,0.000000000e+00)
# + Nout (0.000000000e+00,2.000000000e+02,0.000000000e+00)
# .default
# +  nhinc=1 nwinc=8
# +  sigma=1.577340000e+03
# N1 x=0.000000000e+00 y=2.000000000e+02 z=1.500000000e+00
# N_2 x=8.000000000e+02 y=2.000000000e+02 z=1.500000000e+00
# N_3 x=8.000000000e+02 y=8.000000000e+02 z=1.500000000e+00
# E_4 N1 N_2
# +  w=8.000000000e+00 h=1.000000000e+00
# E_5 N_2 N_3
# +  w=8.000000000e+00 h=1.000000000e+00
# .equiv Nin N_3
# .external N1 Nout
# .freq fmin=1.000000000e-01 fmax=1.000000000e+09 ndec=5.000000000e-02
# .end

# %% [markdown]
# Write example1 to a file.

# %%
open("example1.inp","w") do io
    show(io,example1)
end

# %% [markdown]
# Groups may be transformed.  To demonstrate, example1 is rotated 90deg around x,y,and z axis.

# %%
transform!(example1,rx(0.5π)*ry(0.5π)*rz(0.5π))  # must keep plane parallel to xy, xz, or yz plane

# %% [markdown]
# Write rotated example1 to a file

# %%
open("example1_rotated.inp","w") do io
    show(io,example1)
end

# %% [markdown]
# calling `push!` on a `Group` will push into the groups `elements`.

# %%
# same example, using push!
example1 = Group()
push!(example1,Comment("A FastHenry example using a reference plane"))
push!(example1,Units("mils"))
nin = Node("in",800,800,0)
nout = Node("out",0,200,0)
push!(example1,UniformPlane(x1=0, y1=0, z1=0, x2=1000, y2=0, z2=0, x3=1000, y3=1000, z3=0,
    thick= 1.2, seg1=20, seg2=20, nodes=[nin, nout]))
push!(example1,Default(SegmentParameters(sigma=62.1e6*2.54e-5,nwinc=8, nhinc=1)))
n1 = Node("1",0,200,1.5)
push!(example1,n1)
n2 = Node(800,200,1.5)
push!(example1,n2)
n3 = Node(800,800,1.5)
push!(example1,n3)
sp = SegmentParameters(w=8,h=1)
push!(example1,Segment(n1,n2,sp))
push!(example1,Segment(n2,n3,sp))
push!(example1,Equiv([nin,n3]))
push!(example1,External(n1,nout))
push!(example1,Freq(min=1e-1, max=1e9, ndec=0.05))
push!(example1,End());

# %% [markdown]
# Plot of `example1`

# %%
using Plots
gr() # plotlyjs or plotly for interactive plot
plt=plot(example1)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 141.339,376.378 490.157,376.378 490.157,27.5591 141.339,27.5591
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="141" y="27" width="350" height="350"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   141.339,279.55 300.489,142.028
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.489,142.028 490.157,238.856
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   141.339,265.242 300.489,127.72
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.489,127.72 490.157,224.547
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   141.339,250.933 300.489,113.411
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.489,113.411 490.157,210.239
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   141.339,236.624 300.489,99.1024
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.489,99.1024 490.157,195.93
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   141.339,222.316 300.489,84.7937
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.489,84.7937 490.157,181.621
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   141.339,208.007 300.489,70.485
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.489,70.485 490.157,167.313
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   141.339,193.698 300.489,56.1764
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.489,56.1764 490.157,153.004
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   141.339,179.39 300.489,41.8677
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.489,41.8677 490.157,138.695
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   141.339,165.081 300.489,27.5591
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.489,27.5591 490.157,124.387
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   146.707,282.291 305.857,144.769
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   305.857,144.769 305.857,30.2995
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   191.44,305.127 350.59,167.605
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   350.59,167.605 350.59,53.1362
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   236.173,327.964 395.323,190.442
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   395.323,190.442 395.323,75.9729
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   280.906,350.801 440.056,213.279
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   440.056,213.279 440.056,98.8096
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   325.639,373.638 484.79,236.116
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   484.79,236.116 484.79,121.646
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   145.843,275.658 335.511,372.486
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   145.843,275.658 145.843,161.189
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   183.378,243.224 373.047,340.051
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   183.378,243.224 183.378,128.754
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   220.914,210.789 410.582,307.617
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   220.914,210.789 220.914,96.32
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   258.449,178.355 448.118,275.183
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#ededed; stroke-width:1; stroke-opacity:1; fill:none" points="
#   258.449,178.355 258.449,63.8856
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   295.985,145.921 485.653,242.748
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#cccccc; stroke-width:1; stroke-opacity:1; fill:none" points="
#   295.985,145.921 295.985,31.4512
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   108.25,240.733 114.125,243.732
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   120.326,241.961 117.062,240.294 116.736,243.831 117.062,243.586 118.041,243.674 119.02,244.174 119.999,245.085 120.652,246.242 120.978,247.642 120.978,248.465
#   120.652,249.533 119.999,250.023 119.02,249.934 118.041,249.434 117.062,248.523 116.736,247.945 116.409,246.956
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   124.895,244.293 123.916,244.205 123.263,245.106 122.937,246.996 122.937,248.231 123.263,250.454 123.916,252.022 124.895,252.933 125.548,253.266 126.527,253.355
#   127.179,252.454 127.506,250.563 127.506,249.329 127.179,247.105 126.527,245.538 125.548,244.626 124.895,244.293
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   131.422,247.626 130.443,247.537 129.79,248.438 129.464,250.329 129.464,251.563 129.79,253.787 130.443,255.354 131.422,256.266 132.075,256.599 133.054,256.687
#   133.707,255.786 134.033,253.896 134.033,252.661 133.707,250.438 133.054,248.87 132.075,247.959 131.422,247.626
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   131.422,219.008 1
